# %% [markdown]
# # 作業
# * 試著想想看, 非監督學習是否有可能使用評價函數 (Metric) 來鑑別好壞呢?
# (Hint : 可以分為 "有目標值" 與 "無目標值" 兩個方向思考)

# %% [markdown]
# #### Ans:
# 應該是無法。
# 有目標值的資料因為無法知道正確答案(Label)，因此無法用 Metric 評估預測的好壞。
# 無目標值的資料沒有特定答案，也只是做分群或降維，因此也不法評量。
